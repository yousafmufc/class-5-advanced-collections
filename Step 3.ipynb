# %% [markdown]
# ## Step 3: Group by customers and invoice number
#
# We're adding another level of nesting. Inside each customer group, we'll group also by invoice. So we can have a list of all the invoices of a customer.
#
# If we start with the following products string:

# %%
products_string = """
536364,85123A,WHITE HANGING HEART T-LIGHT HOLDER,6,12/1/10 08:26,2.55,17850,United Kingdom

536365,71053,WHITE METAL LANTERN,6,12/1/10 08:26,3.39,17850,United Kingdom
536365,84406B,CREAM CUPID HEARTS COAT HANGER,8,12/1/10 08:26,2.75,17850,United Kingdom
536365,84029G,KNITTED UNION FLAG HOT WATER BOTTLE,6,12/1/10 08:26,3.39,17850,United Kingdom
536365,84029E,RED WOOLLY HOTTIE WHITE HEART.,6,12/1/10 08:26,3.39,17850,United Kingdom


536366,22752,SET 7 BABUSHKA NESTING BOXES,2,12/1/10 08:26,7.65,17851,United Kingdom
536366,21730,GLASS STAR FROSTED T-LIGHT HOLDER,6,12/1/10 08:26,4.25,17851,United Kingdom
536366,22633,HAND WARMER UNION JACK,6,12/1/10 08:28,1.85,17851,United Kingdom
536366,22632,HAND WARMER RED POLKA DOT,6,12/1/10 08:28,1.85,17851,United Kingdom

"""

# %% [markdown]
# You'll notice 3 "groups" (separated by blank lines).

# %% [markdown]
# ### Write the function
#
# The function `group_products_by_customer_and_invoice` should create the following dictionary:

# %%
{
  '17850': {
    '536365': [
      ['536365',
        '85123A',
        'WHITE HANGING HEART T-LIGHT HOLDER',
        '6',
        '12/1/10 08:26',
        '2.55',
        '17850',
        'United Kingdom'
      ],
      ['536365',
        '71053',
        'WHITE METAL LANTERN',
        '6',
        '12/1/10 08:26',
        '3.39',
        '17850',
        'United Kingdom'
      ],
      ['536365',
        '84406B',
        'CREAM CUPID HEARTS COAT HANGER',
        '8',
        '12/1/10 08:26',
        '2.75',
        '17850',
        'United Kingdom'
      ],
      ['536365',
        '84029G',
        'KNITTED UNION FLAG HOT WATER BOTTLE',
        '6',
        '12/1/10 08:26',
        '3.39',
        '17850',
        'United Kingdom'
      ],
      ['536365',
        '84029E',
        'RED WOOLLY HOTTIE WHITE HEART.',
        '6',
        '12/1/10 08:26',
        '3.39',
        '17850',
        'United Kingdom'
      ]
    ]
  },
  '17851': {
    '536365': [
      ['536365',
        '22752',
        'SET 7 BABUSHKA NESTING BOXES',
        '2',
        '12/1/10 08:26',
        '7.65',
        '17851',
        'United Kingdom'
      ],
      ['536365',
        '21730',
        'GLASS STAR FROSTED T-LIGHT HOLDER',
        '6',
        '12/1/10 08:26',
        '4.25',
        '17851',
        'United Kingdom'
      ]
    ],
    '536366': [
      ['536366',
        '22633',
        'HAND WARMER UNION JACK',
        '6',
        '12/1/10 08:28',
        '1.85',
        '17851',
        'United Kingdom'
      ],
      ['536366',
        '22632',
        'HAND WARMER RED POLKA DOT',
        '6',
        '12/1/10 08:28',
        '1.85',
        '17851',
        'United Kingdom'
      ]
    ]
  }
}
# Out:
# {'17850': {'536365': [['536365',
#     '85123A',
#     'WHITE HANGING HEART T-LIGHT HOLDER',
#     '6',
#     '12/1/10 08:26',
#     '2.55',
#     '17850',
#     'United Kingdom'],
#    ['536365',
#     '71053',
#     'WHITE METAL LANTERN',
#     '6',
#     '12/1/10 08:26',
#     '3.39',
#     '17850',
#     'United Kingdom'],
#    ['536365',
#     '84406B',
#     'CREAM CUPID HEARTS COAT HANGER',
#     '8',
#     '12/1/10 08:26',
#     '2.75',
#     '17850',
#     'United Kingdom'],
#    ['536365',
#     '84029G',
#     'KNITTED UNION FLAG HOT WATER BOTTLE',
#     '6',
#     '12/1/10 08:26',
#     '3.39',
#     '17850',
#     'United Kingdom'],
#    ['536365',
#     '84029E',
#     'RED WOOLLY HOTTIE WHITE HEART.',
#     '6',
#     '12/1/10 08:26',
#     '3.39',
#     '17850',
#     'United Kingdom']]},
#  '17851': {'536365': [['536365',
#     '22752',
#     'SET 7 BABUSHKA NESTING BOXES',
#     '2',
#     '12/1/10 08:26',
#     '7.65',
#     '17851',
#     'United Kingdom'],
# ...

# %%
from step_1 import transform_products_to_list

# %%
def group_products_by_customer_and_invoice(products_string):
    pass

# %%
assert group_products_by_customer_and_invoice(products_string) == {
  '17850': {
    '536365': [
      ['536365',
        '85123A',
        'WHITE HANGING HEART T-LIGHT HOLDER',
        '6',
        '12/1/10 08:26',
        '2.55',
        '17850',
        'United Kingdom'
      ],
      ['536365',
        '71053',
        'WHITE METAL LANTERN',
        '6',
        '12/1/10 08:26',
        '3.39',
        '17850',
        'United Kingdom'
      ],
      ['536365',
        '84406B',
        'CREAM CUPID HEARTS COAT HANGER',
        '8',
        '12/1/10 08:26',
        '2.75',
        '17850',
        'United Kingdom'
      ],
      ['536365',
        '84029G',
        'KNITTED UNION FLAG HOT WATER BOTTLE',
        '6',
        '12/1/10 08:26',
        '3.39',
        '17850',
        'United Kingdom'
      ],
      ['536365',
        '84029E',
        'RED WOOLLY HOTTIE WHITE HEART.',
        '6',
        '12/1/10 08:26',
        '3.39',
        '17850',
        'United Kingdom'
      ]
    ]
  },
  '17851': {
    '536365': [
      ['536365',
        '22752',
        'SET 7 BABUSHKA NESTING BOXES',
        '2',
        '12/1/10 08:26',
        '7.65',
        '17851',
        'United Kingdom'
      ],
      ['536365',
        '21730',
        'GLASS STAR FROSTED T-LIGHT HOLDER',
        '6',
        '12/1/10 08:26',
        '4.25',
        '17851',
        'United Kingdom'
      ]
    ],
    '536366': [
      ['536366',
        '22633',
        'HAND WARMER UNION JACK',
        '6',
        '12/1/10 08:28',
        '1.85',
        '17851',
        'United Kingdom'
      ],
      ['536366',
        '22632',
        'HAND WARMER RED POLKA DOT',
        '6',
        '12/1/10 08:28',
        '1.85',
        '17851',
        'United Kingdom'
      ]
    ]
  }
}

# %% [markdown]
# ### Done? Run the tests!
#
# If you're done with your solution, copy the function inside `step_3.py` and run the tests to verify everything is working:
#
# ```bash
# $ py.test tests.py -k step_3
# ```
